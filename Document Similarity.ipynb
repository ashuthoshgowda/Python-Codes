# %%
from goose import Goose
import requests
url = 'https://www.datacubes.com/jobs/data-scientist.html'
g = Goose()
page = requests.get('https://www.datacubes.com/')
article = g.extract(url=url)
article.title
# Out:
# u'Data Scientist Open Position - DataCubes'

# %%
article.meta_description
# Out:
# ''

# %%
article.cleaned_text
# Out:
# u'We are seeking intellectually curious and passionate candidates who relentlessly challenge the norm and seek progress through creative disruption.'

# %%
from bs4 import BeautifulSoup

# %%
import nltk   
from urllib import urlopen
import re
url = 'https://www.datacubes.com/jobs/data-scientist.html' 
url2='https://www.datacubes.com/jobs/dev-ops-engineer.html'
url3='https://www.datacubes.com/jobs/hadoop-developer.html'
html = urlopen(url).read()    
soup = BeautifulSoup(html)
text = soup.get_text()

html = urlopen(url2).read()    
soup = BeautifulSoup(html)
text2 = soup.get_text()

html = urlopen(url3).read()    
soup = BeautifulSoup(html)
text3 = soup.get_text()

#print(text)
#text= str(text)

#print re.search('Start(.*?)OPENINGS', text).group(0)

# %%
dsjd=text
dojd=text2
hdjd=text3

# %%
import PyPDF2
pdfFileObj = open('C:/Users/Ashuthosh/Desktop/10.24.2016/ASHUTHOSH_GOWDA.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
pdfReader.numPages
pageObj = pdfReader.getPage(0)
resume=pageObj.extractText()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
vectorizer = TfidfVectorizer(stop_words='english')
tfidf = vectorizer.fit_transform([dsjd,dojd,hdjd, resume])
pairwise_similarity = tfidf * tfidf.T

# %%
print(pairwise_similarity)
# Out:
#   (0, 3)	0.207637730108
#   (0, 2)	0.587389879707
#   (0, 1)	0.503703774039
#   (0, 0)	1.0
#   (1, 0)	0.503703774039
#   (1, 2)	0.538697476209
#   (1, 3)	0.0716388553629
#   (1, 1)	1.0
#   (2, 0)	0.587389879707
#   (2, 1)	0.538697476209
#   (2, 3)	0.199361410144
#   (2, 2)	1.0
#   (3, 0)	0.207637730108
#   (3, 1)	0.0716388553629
#   (3, 2)	0.199361410144
#   (3, 3)	1.0

# %%
final = " ".join([word for word in resume.split()])

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
import random

from wordcloud import WordCloud, STOPWORDS

text = 'all your base are belong to us all of your base base base'
wordcloud = WordCloud(
                          stopwords=STOPWORDS,
                          background_color='black',
                        
                          ).generate(final)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
#plt.savefig('Kaaju.png', bbox_inches='tight')
